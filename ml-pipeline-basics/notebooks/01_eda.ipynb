# %%
import sys
sys.path.append("..")

from src.data import load_dataset

df = load_dataset()
df.shape
# Out:
# (1309, 14)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# body         1188
# cabin        1014
# boat          823
# home.dest     564
# age           263
# embarked        2
# fare            1
# pclass          0
# survived        0
# name            0
# sex             0
# sibsp           0
# parch           0
# ticket          0
# dtype: int64

# %%
df["survived"].value_counts(dropna=False)
df["survived"].value_counts(normalize=True, dropna=False)
# Out:
# survived
# 0    0.618029
# 1    0.381971
# Name: proportion, dtype: float64

# %%
df.dtypes.astype(str).sort_values()
# Out:
# survived     category
# sex          category
# embarked     category
# age           float64
# fare          float64
# body          float64
# pclass          int64
# sibsp           int64
# parch           int64
# name              str
# ticket            str
# cabin             str
# boat              str
# home.dest         str
# dtype: str

# %%
df[["survived", "sex", "pclass", "age", "fare", "embarked"]].head()
# Out:
#   survived     sex  pclass      age      fare embarked
# 0        1  female       1  29.0000  211.3375        S
# 1        1    male       1   0.9167  151.5500        S
# 2        0  female       1   2.0000  151.5500        S
# 3        0    male       1  30.0000  151.5500        S
# 4        0  female       1  25.0000  151.5500        S

# %%
df.groupby("sex")["survived"].apply(lambda x: x.astype(int).mean())
# Out:
# sex
# female    0.727468
# male      0.190985
# Name: survived, dtype: float64

# %%
df.groupby("pclass")["survived"].apply(lambda x: x.astype(int).mean())
# Out:
# pclass
# 1    0.619195
# 2    0.429603
# 3    0.255289
# Name: survived, dtype: float64
